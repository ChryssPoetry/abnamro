# %%
#importing the pandas library
import pandas as pd

# %%
#loading the datasets into various respective variables
creditDatasets = pd.read_csv("/Users/chrysspoetry/abnamro/datasets/credit_applications.csv")
customers = pd.read_csv("/Users/chrysspoetry/abnamro/datasets/customers.csv")

# %%
#checking out its contents
customers
# Out:
#        Unnamed: 0  client_nr  yearmonth  total_nr_trx  nr_debit_trx  \
# 0               1          1     201401            97            50
# 1               2          1     201402            88            59
# 2               3          1     201403            96            62
# 3               4          1     201404            83            53
# 4               5          1     201405            94            54
# ...           ...        ...        ...           ...           ...
# 29991       29992       1000     201604             2             1
# 29992       29993       1000     201605             5             3
# 29993       29994       1000     201606             4             3
# 29994       29995       1000     201607             4             2
# 29995       29996       1000     201608             3             1
#
#        volume_debit_trx  nr_credit_trx  volume_credit_trx  min_balance  \
# 0               6527929             47            7454863     -7914288
# 1               3475918             29            1895848     -8448513
# 2              31316405             34           20083583    -10347650
# 3              18669967             30            1091295    -15385039
# 4               2893905             40            2034075    -15682170
# ...                 ...            ...                ...          ...
# 29991            605000              1             315800       131422
# 29992            607506              2            1210000       128916
# 29993           1211270              1             605000       127646
# 29994            606253              2             920000       441393
# 29995              1261              2            1210000      1045132
#
#        max_balance  CRG
# 0         25110651  1.0
# 1         25036651  1.0
# 2         18020151  1.0
# 3         13318200  1.0
# 4          2350000  1.0
# ...            ...  ...
# 29991       736422  NaN
# 29992       735145  NaN
# 29993      1338916  NaN
# 29994      1047646  NaN
# 29995      1650132  NaN
#
# [29996 rows x 11 columns]

# %%
#displaying the contents of the credit dataset
creditDatasets
# Out:
#        Unnamed: 0  client_nr  yearmonth  credit_application  \
# 0               1          1     201401                   0
# 1               2          1     201402                   0
# 2               3          1     201403                   0
# 3               4          1     201404                   0
# 4               5          1     201405                   0
# ...           ...        ...        ...                 ...
# 29991       29992       1000     201604                   0
# 29992       29993       1000     201605                   0
# 29993       29994       1000     201606                   0
# 29994       29995       1000     201607                   0
# 29995       29996       1000     201608                   0
#
#        nr_credit_applications
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 29991                       0
# 29992                       0
# 29993                       0
# 29994                       0
# 29995                       0
#
# [29996 rows x 5 columns]

# %%
#converting the yearmonth to a more suitable format
import datetime
creditDateTime = pd.to_datetime(creditDatasets['yearmonth'], format="%Y%m")
creditDateTime
# Out:
# 0       2014-01-01
# 1       2014-02-01
# 2       2014-03-01
# 3       2014-04-01
# 4       2014-05-01
#            ...
# 29991   2016-04-01
# 29992   2016-05-01
# 29993   2016-06-01
# 29994   2016-07-01
# 29995   2016-08-01
# Name: yearmonth, Length: 29996, dtype: datetime64[ns]

# %%
customersDate = pd.to_datetime(customers['yearmonth'], format = "%Y%m")
customersDate
# Out:
# 0       2014-01-01
# 1       2014-02-01
# 2       2014-03-01
# 3       2014-04-01
# 4       2014-05-01
#            ...
# 29991   2016-04-01
# 29992   2016-05-01
# 29993   2016-06-01
# 29994   2016-07-01
# 29995   2016-08-01
# Name: yearmonth, Length: 29996, dtype: datetime64[ns]

# %%
#loading the converted time into the datasets
customers['Year'] = customersDate
creditDatasets["Year"] = creditDateTime

# %%
customers
# Out:
#        Unnamed: 0  client_nr  yearmonth  total_nr_trx  nr_debit_trx  \
# 0               1          1     201401            97            50
# 1               2          1     201402            88            59
# 2               3          1     201403            96            62
# 3               4          1     201404            83            53
# 4               5          1     201405            94            54
# ...           ...        ...        ...           ...           ...
# 29991       29992       1000     201604             2             1
# 29992       29993       1000     201605             5             3
# 29993       29994       1000     201606             4             3
# 29994       29995       1000     201607             4             2
# 29995       29996       1000     201608             3             1
#
#        volume_debit_trx  nr_credit_trx  volume_credit_trx  min_balance  \
# 0               6527929             47            7454863     -7914288
# 1               3475918             29            1895848     -8448513
# 2              31316405             34           20083583    -10347650
# 3              18669967             30            1091295    -15385039
# 4               2893905             40            2034075    -15682170
# ...                 ...            ...                ...          ...
# 29991            605000              1             315800       131422
# 29992            607506              2            1210000       128916
# 29993           1211270              1             605000       127646
# 29994            606253              2             920000       441393
# 29995              1261              2            1210000      1045132
#
#        max_balance  CRG       Year
# 0         25110651  1.0 2014-01-01
# 1         25036651  1.0 2014-02-01
# 2         18020151  1.0 2014-03-01
# 3         13318200  1.0 2014-04-01
# 4          2350000  1.0 2014-05-01
# ...            ...  ...        ...
# 29991       736422  NaN 2016-04-01
# 29992       735145  NaN 2016-05-01
# 29993      1338916  NaN 2016-06-01
# 29994      1047646  NaN 2016-07-01
# 29995      1650132  NaN 2016-08-01
#
# [29996 rows x 12 columns]

# %%
creditDatasets
# Out:
#        Unnamed: 0  client_nr  yearmonth  credit_application  \
# 0               1          1     201401                   0
# 1               2          1     201402                   0
# 2               3          1     201403                   0
# 3               4          1     201404                   0
# 4               5          1     201405                   0
# ...           ...        ...        ...                 ...
# 29991       29992       1000     201604                   0
# 29992       29993       1000     201605                   0
# 29993       29994       1000     201606                   0
# 29994       29995       1000     201607                   0
# 29995       29996       1000     201608                   0
#
#        nr_credit_applications       Year
# 0                           0 2014-01-01
# 1                           0 2014-02-01
# 2                           0 2014-03-01
# 3                           0 2014-04-01
# 4                           0 2014-05-01
# ...                       ...        ...
# 29991                       0 2016-04-01
# 29992                       0 2016-05-01
# 29993                       0 2016-06-01
# 29994                       0 2016-07-01
# 29995                       0 2016-08-01
#
# [29996 rows x 6 columns]

# %%
#saving the first snapshot of the new data
creditSnapshot = creditDatasets.copy()
customerSnapshot = customers.copy()

# %%
import matplotlib.pyplot as plt

# %%
creditSnapshot
# Out:
#        Unnamed: 0  client_nr  yearmonth  credit_application  \
# 0               1          1     201401                   0
# 1               2          1     201402                   0
# 2               3          1     201403                   0
# 3               4          1     201404                   0
# 4               5          1     201405                   0
# ...           ...        ...        ...                 ...
# 29991       29992       1000     201604                   0
# 29992       29993       1000     201605                   0
# 29993       29994       1000     201606                   0
# 29994       29995       1000     201607                   0
# 29995       29996       1000     201608                   0
#
#        nr_credit_applications       Year
# 0                           0 2014-01-01
# 1                           0 2014-02-01
# 2                           0 2014-03-01
# 3                           0 2014-04-01
# 4                           0 2014-05-01
# ...                       ...        ...
# 29991                       0 2016-04-01
# 29992                       0 2016-05-01
# 29993                       0 2016-06-01
# 29994                       0 2016-07-01
# 29995                       0 2016-08-01
#
# [29996 rows x 6 columns]

# %%
df_credit = creditDatasets.drop('yearmonth', axis=1)
df_credit
# Out:
#        Unnamed: 0  client_nr  credit_application  nr_credit_applications  \
# 0               1          1                   0                       0
# 1               2          1                   0                       0
# 2               3          1                   0                       0
# 3               4          1                   0                       0
# 4               5          1                   0                       0
# ...           ...        ...                 ...                     ...
# 29991       29992       1000                   0                       0
# 29992       29993       1000                   0                       0
# 29993       29994       1000                   0                       0
# 29994       29995       1000                   0                       0
# 29995       29996       1000                   0                       0
#
#             Year
# 0     2014-01-01
# 1     2014-02-01
# 2     2014-03-01
# 3     2014-04-01
# 4     2014-05-01
# ...          ...
# 29991 2016-04-01
# 29992 2016-05-01
# 29993 2016-06-01
# 29994 2016-07-01
# 29995 2016-08-01
#
# [29996 rows x 5 columns]

# %%
df_customers = customers.drop('yearmonth', axis=1)
df_customers
# Out:
#        Unnamed: 0  client_nr  total_nr_trx  nr_debit_trx  volume_debit_trx  \
# 0               1          1            97            50           6527929
# 1               2          1            88            59           3475918
# 2               3          1            96            62          31316405
# 3               4          1            83            53          18669967
# 4               5          1            94            54           2893905
# ...           ...        ...           ...           ...               ...
# 29991       29992       1000             2             1            605000
# 29992       29993       1000             5             3            607506
# 29993       29994       1000             4             3           1211270
# 29994       29995       1000             4             2            606253
# 29995       29996       1000             3             1              1261
#
#        nr_credit_trx  volume_credit_trx  min_balance  max_balance  CRG  \
# 0                 47            7454863     -7914288     25110651  1.0
# 1                 29            1895848     -8448513     25036651  1.0
# 2                 34           20083583    -10347650     18020151  1.0
# 3                 30            1091295    -15385039     13318200  1.0
# 4                 40            2034075    -15682170      2350000  1.0
# ...              ...                ...          ...          ...  ...
# 29991              1             315800       131422       736422  NaN
# 29992              2            1210000       128916       735145  NaN
# 29993              1             605000       127646      1338916  NaN
# 29994              2             920000       441393      1047646  NaN
# 29995              2            1210000      1045132      1650132  NaN
#
#             Year
# 0     2014-01-01
# 1     2014-02-01
# 2     2014-03-01
# 3     2014-04-01
# 4     2014-05-01
# ...          ...
# 29991 2016-04-01
# 29992 2016-05-01
# 29993 2016-06-01
# 29994 2016-07-01
# 29995 2016-08-01
#
# [29996 rows x 11 columns]

# %%
df_customers
# Out:
#        Unnamed: 0  client_nr  total_nr_trx  nr_debit_trx  volume_debit_trx  \
# 0               1          1            97            50           6527929
# 1               2          1            88            59           3475918
# 2               3          1            96            62          31316405
# 3               4          1            83            53          18669967
# 4               5          1            94            54           2893905
# ...           ...        ...           ...           ...               ...
# 29991       29992       1000             2             1            605000
# 29992       29993       1000             5             3            607506
# 29993       29994       1000             4             3           1211270
# 29994       29995       1000             4             2            606253
# 29995       29996       1000             3             1              1261
#
#        nr_credit_trx  volume_credit_trx  min_balance  max_balance  CRG  \
# 0                 47            7454863     -7914288     25110651  1.0
# 1                 29            1895848     -8448513     25036651  1.0
# 2                 34           20083583    -10347650     18020151  1.0
# 3                 30            1091295    -15385039     13318200  1.0
# 4                 40            2034075    -15682170      2350000  1.0
# ...              ...                ...          ...          ...  ...
# 29991              1             315800       131422       736422  NaN
# 29992              2            1210000       128916       735145  NaN
# 29993              1             605000       127646      1338916  NaN
# 29994              2             920000       441393      1047646  NaN
# 29995              2            1210000      1045132      1650132  NaN
#
#             Year  flexaccount  business
# 0     2014-01-01         True     False
# 1     2014-02-01         True     False
# 2     2014-03-01         True     False
# 3     2014-04-01         True     False
# 4     2014-05-01         True     False
# ...          ...          ...       ...
# 29991 2016-04-01        False      True
# 29992 2016-05-01        False      True
# 29993 2016-06-01        False      True
# 29994 2016-07-01        False      True
# 29995 2016-08-01        False      True
#
# [29996 rows x 13 columns]

# %%
df_customers
# Out:
#        client_nr  total_nr_trx  nr_debit_trx  volume_debit_trx  nr_credit_trx  \
# 0              1            97            50           6527929             47
# 1              1            88            59           3475918             29
# 2              1            96            62          31316405             34
# 3              1            83            53          18669967             30
# 4              1            94            54           2893905             40
# ...          ...           ...           ...               ...            ...
# 29991       1000             2             1            605000              1
# 29992       1000             5             3            607506              2
# 29993       1000             4             3           1211270              1
# 29994       1000             4             2            606253              2
# 29995       1000             3             1              1261              2
#
#        volume_credit_trx  min_balance  max_balance  CRG       Year
# 0                7454863     -7914288     25110651  1.0 2014-01-01
# 1                1895848     -8448513     25036651  1.0 2014-02-01
# 2               20083583    -10347650     18020151  1.0 2014-03-01
# 3                1091295    -15385039     13318200  1.0 2014-04-01
# 4                2034075    -15682170      2350000  1.0 2014-05-01
# ...                  ...          ...          ...  ...        ...
# 29991             315800       131422       736422  NaN 2016-04-01
# 29992            1210000       128916       735145  NaN 2016-05-01
# 29993             605000       127646      1338916  NaN 2016-06-01
# 29994             920000       441393      1047646  NaN 2016-07-01
# 29995            1210000      1045132      1650132  NaN 2016-08-01
#
# [29996 rows x 10 columns]

# %%
df = pd.merge(df_customers, creditDatasets, how = "inner", on='client_nr')

# %%
df
# Out:
#         client_nr  total_nr_trx  nr_debit_trx  volume_debit_trx  \
# 0               1            97            50           6527929
# 1               1            97            50           6527929
# 2               1            97            50           6527929
# 3               1            97            50           6527929
# 4               1            97            50           6527929
# ...           ...           ...           ...               ...
# 939687       1000             3             1              1261
# 939688       1000             3             1              1261
# 939689       1000             3             1              1261
# 939690       1000             3             1              1261
# 939691       1000             3             1              1261
#
#         nr_credit_trx  volume_credit_trx  min_balance  max_balance  CRG  \
# 0                  47            7454863     -7914288     25110651  1.0
# 1                  47            7454863     -7914288     25110651  1.0
# 2                  47            7454863     -7914288     25110651  1.0
# 3                  47            7454863     -7914288     25110651  1.0
# 4                  47            7454863     -7914288     25110651  1.0
# ...               ...                ...          ...          ...  ...
# 939687              2            1210000      1045132      1650132  NaN
# 939688              2            1210000      1045132      1650132  NaN
# 939689              2            1210000      1045132      1650132  NaN
# 939690              2            1210000      1045132      1650132  NaN
# 939691              2            1210000      1045132      1650132  NaN
#
#            Year_x  yearmonth  credit_application  nr_credit_applications  \
# 0      2014-01-01     201401                   0                       0
# 1      2014-01-01     201402                   0                       0
# 2      2014-01-01     201403                   0                       0
# 3      2014-01-01     201404                   0                       0
# 4      2014-01-01     201405                   0                       0
# ...           ...        ...                 ...                     ...
# 939687 2016-08-01     201604                   0                       0
# 939688 2016-08-01     201605                   0                       0
# 939689 2016-08-01     201606                   0                       0
# 939690 2016-08-01     201607                   0                       0
# 939691 2016-08-01     201608                   0                       0
#
#            Year_y
# 0      2014-01-01
# 1      2014-02-01
# 2      2014-03-01
# 3      2014-04-01
# 4      2014-05-01
# ...           ...
# 939687 2016-04-01
# 939688 2016-05-01
# 939689 2016-06-01
# 939690 2016-07-01
# 939691 2016-08-01
#
# [939692 rows x 14 columns]

# %%
df
#dropped the yearmonth and year_x coloumns
# Out:
#         client_nr  total_nr_trx  nr_debit_trx  volume_debit_trx  \
# 0               1            97            50           6527929
# 1               1            97            50           6527929
# 2               1            97            50           6527929
# 3               1            97            50           6527929
# 4               1            97            50           6527929
# ...           ...           ...           ...               ...
# 939687       1000             3             1              1261
# 939688       1000             3             1              1261
# 939689       1000             3             1              1261
# 939690       1000             3             1              1261
# 939691       1000             3             1              1261
#
#         nr_credit_trx  volume_credit_trx  min_balance  max_balance  CRG  \
# 0                  47            7454863     -7914288     25110651  1.0
# 1                  47            7454863     -7914288     25110651  1.0
# 2                  47            7454863     -7914288     25110651  1.0
# 3                  47            7454863     -7914288     25110651  1.0
# 4                  47            7454863     -7914288     25110651  1.0
# ...               ...                ...          ...          ...  ...
# 939687              2            1210000      1045132      1650132  NaN
# 939688              2            1210000      1045132      1650132  NaN
# 939689              2            1210000      1045132      1650132  NaN
# 939690              2            1210000      1045132      1650132  NaN
# 939691              2            1210000      1045132      1650132  NaN
#
#         credit_application  nr_credit_applications     Year_y
# 0                        0                       0 2014-01-01
# 1                        0                       0 2014-02-01
# 2                        0                       0 2014-03-01
# 3                        0                       0 2014-04-01
# 4                        0                       0 2014-05-01
# ...                    ...                     ...        ...
# 939687                   0                       0 2016-04-01
# 939688                   0                       0 2016-05-01
# 939689                   0                       0 2016-06-01
# 939690                   0                       0 2016-07-01
# 939691                   0                       0 2016-08-01
#
# [939692 rows x 12 columns]

# %%
df =
